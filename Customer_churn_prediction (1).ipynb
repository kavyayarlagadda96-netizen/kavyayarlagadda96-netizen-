# %%
import pandas as pd

df = pd.read_excel('Desktop/Customer churn prediction.xlsx')
df.head()
# Out:
#   Customer_ID Operator  Gender  Age  Tenure_Months Plan_Type Network_Type  \
# 0    CUST0001      Jio    Male   19             20   Prepaid           4G
# 1    CUST0002     BSNL  Female   23              1   Prepaid           4G
# 2    CUST0003   Airtel  Female   45             72   Prepaid           4G
# 3    CUST0004   Airtel  Female   46             63   Prepaid           4G
# 4    CUST0005      Jio  Female   43             67   Prepaid           4G
#
#    Monthly_Charges  Data_Usage_GB  Calls_Per_Month  Complaints Payment_Method  \
# 0           870.83           34.7              518           0            UPI
# 1          1161.21           22.7              261           2            UPI
# 2          1018.91           10.8             1185           2            UPI
# 3           913.49            8.4             1081           2    Credit Card
# 4          1095.71           48.5              853           2           Cash
#
#   Recharge_Frequency Churn
# ...

# %%
# ==========================================
# CUSTOMER CHURN PREDICTION - EDA
# Jio, Airtel, Vi and BSNL
# ==========================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ------------------------------------------
# 1. 'Load Dataset'
# ------------------------------------------

df = pd.read_excel(r'C:\Users\kavyayarlagadda\Desktop/Customer churn prediction.xlsx')


print("Dataset loaded successfully!")

# ------------------------------------------
# 2. Display Dataset
# ------------------------------------------

print("\nFirst 5 Rows:")
print(df.head())

print("\nLast 5 Rows:")
print(df.tail())

# ------------------------------------------
# 3. Dataset Information
# ------------------------------------------

print("\nDataset Information:")
print(df.info())

# ------------------------------------------
# 4. Dataset Shape
# ------------------------------------------

print("\nNumber of Rows and Columns:")
print(df.shape)

# ------------------------------------------
# 5. Column Names
# ------------------------------------------

print("\nColumn Names:")
print(df.columns)

# ------------------------------------------
# 6. Statistical Summary
# ------------------------------------------

print("\nStatistical Summary:")
print(df.describe())

# ------------------------------------------
# 7. Missing Values
# ------------------------------------------

print("\nMissing Values:")
print(df.isnull().sum())

# ------------------------------------------
# 8. Duplicate Values
# ------------------------------------------

print("\nNumber of Duplicate Rows:")
print(df.duplicated().sum())

# ------------------------------------------
# 9. Unique Values
# ------------------------------------------

print("\nUnique Values:")
for column in df.columns:
    print(
        column,
        "->",
        df[column].nunique()
    )

# ==========================================
# VISUALIZATION
# ==========================================

# ------------------------------------------
# 10. Churn Distribution
# ------------------------------------------

churn_count = df["Churn"].value_counts()

plt.figure(figsize=(6, 5))

plt.bar(
    churn_count.index,
    churn_count.values
)

plt.title("Customer Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")

plt.show()

# ------------------------------------------
# 11. Operator Distribution
# ------------------------------------------

operator_count = df["Operator"].value_counts()

plt.figure(figsize=(7, 5))

plt.bar(
    operator_count.index,
    operator_count.values
)

plt.title("Customers by Telecom Operator")
plt.xlabel("Operator")
plt.ylabel("Number of Customers")

plt.show()

# ------------------------------------------
# 12. Churn by Operator
# ------------------------------------------

operator_churn = pd.crosstab(
    df["Operator"],
    df["Churn"]
)

operator_churn.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Churn by Telecom Operator")
plt.xlabel("Operator")
plt.ylabel("Number of Customers")

plt.xticks(rotation=0)

plt.show()

# ------------------------------------------
# 13. Age Distribution
# ------------------------------------------

plt.figure(figsize=(8, 5))

plt.hist(
    df["Age"],
    bins=10
)

plt.title("Customer Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Customers")

plt.show()

# ------------------------------------------
# 14. Monthly Charges Distribution
# ------------------------------------------

plt.figure(figsize=(8, 5))

plt.hist(
    df["Monthly_Charges"],
    bins=20
)

plt.title("Monthly Charges Distribution")
plt.xlabel("Monthly Charges")
plt.ylabel("Number of Customers")

plt.show()

# ------------------------------------------
# 15. Data Usage Distribution
# ------------------------------------------

plt.figure(figsize=(8, 5))

plt.hist(
    df["Data_Usage_GB"],
    bins=20
)

plt.title("Data Usage Distribution")
plt.xlabel("Data Usage (GB)")
plt.ylabel("Number of Customers")

plt.show()

# ------------------------------------------
# 16. Tenure Distribution
# ------------------------------------------

plt.figure(figsize=(8, 5))

plt.hist(
    df["Tenure_Months"],
    bins=20
)

plt.title("Customer Tenure Distribution")
plt.xlabel("Tenure (Months)")
plt.ylabel("Number of Customers")

plt.show()

# ------------------------------------------
# 17. Plan Type Distribution
# ------------------------------------------

plan_count = df["Plan_Type"].value_counts()

plt.figure(figsize=(6, 5))

plt.bar(
    plan_count.index,
    plan_count.values
)

plt.title("Prepaid vs Postpaid Customers")
plt.xlabel("Plan Type")
plt.ylabel("Number of Customers")

plt.show()

# ------------------------------------------
# 18. Churn by Plan Type
# ------------------------------------------

plan_churn = pd.crosstab(
    df["Plan_Type"],
    df["Churn"]
)

plan_churn.plot(
    kind="bar",
    figsize=(7, 5)
)

plt.title("Churn by Plan Type")
plt.xlabel("Plan Type")
plt.ylabel("Number of Customers")

plt.xticks(rotation=0)

plt.show()

# ------------------------------------------
# 19. Churn vs Monthly Charges
# ------------------------------------------

plt.figure(figsize=(8, 5))

df.boxplot(
    column="Monthly_Charges",
    by="Churn"
)

plt.title("Monthly Charges vs Churn")
plt.suptitle("")

plt.xlabel("Churn")
plt.ylabel("Monthly Charges")

plt.show()

# ------------------------------------------
# 20. Churn vs Tenure
# ------------------------------------------

plt.figure(figsize=(8, 5))

df.boxplot(
    column="Tenure_Months",
    by="Churn"
)

plt.title("Tenure vs Churn")
plt.suptitle("")

plt.xlabel("Churn")
plt.ylabel("Tenure (Months)")

plt.show()

# ------------------------------------------
# 21. Churn vs Data Usage
# ------------------------------------------

plt.figure(figsize=(8, 5))

df.boxplot(
    column="Data_Usage_GB",
    by="Churn"
)

plt.title("Data Usage vs Churn")
plt.suptitle("")

plt.xlabel("Churn")
plt.ylabel("Data Usage (GB)")

plt.show()

# ------------------------------------------
# 22. Complaints vs Churn
# ------------------------------------------

complaint_churn = pd.crosstab(
    df["Complaints"],
    df["Churn"]
)

complaint_churn.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Complaints vs Customer Churn")
plt.xlabel("Number of Complaints")
plt.ylabel("Number of Customers")

plt.xticks(rotation=0)

plt.show()

# ------------------------------------------
# 23. Recharge Frequency vs Churn
# ------------------------------------------

recharge_churn = pd.crosstab(
    df["Recharge_Frequency"],
    df["Churn"]
)

recharge_churn.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Recharge Frequency vs Churn")
plt.xlabel("Recharge Frequency")
plt.ylabel("Number of Customers")

plt.xticks(rotation=0)

plt.show()

# ------------------------------------------
# 24. Payment Method vs Churn
# ------------------------------------------

payment_churn = pd.crosstab(
    df["Payment_Method"],
    df["Churn"]
)

payment_churn.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Payment Method vs Churn")
plt.xlabel("Payment Method")
plt.ylabel("Number of Customers")

plt.xticks(rotation=20)

plt.show()

# ------------------------------------------
# 25. Network Type vs Churn
# ------------------------------------------

network_churn = pd.crosstab(
    df["Network_Type"],
    df["Churn"]
)

network_churn.plot(
    kind="bar",
    figsize=(7, 5)
)

plt.title("Network Type vs Churn")
plt.xlabel("Network Type")
plt.ylabel("Number of Customers")

plt.xticks(rotation=0)

plt.show()

# ------------------------------------------
# 26. Gender vs Churn
# ------------------------------------------

gender_churn = pd.crosstab(
    df["Gender"],
    df["Churn"]
)

gender_churn.plot(
    kind="bar",
    figsize=(7, 5)
)

plt.title("Gender vs Customer Churn")
plt.xlabel("Gender")
plt.ylabel("Number of Customers")

plt.xticks(rotation=0)

plt.show()

# ==========================================
# NUMERICAL CORRELATION
# ==========================================

# ------------------------------------------
# 27. Convert Categorical Data to Numbers
# ------------------------------------------

numeric_df = df.copy()

categorical_columns = numeric_df.select_dtypes(
    include="object"
).columns

for column in categorical_columns:
    numeric_df[column] = (
        numeric_df[column]
        .astype("category")
        .cat.codes
    )

# ------------------------------------------
# 28. Correlation Matrix
# ------------------------------------------

correlation = numeric_df.corr()

print("\nCorrelation Matrix:")
print(correlation)

plt.figure(figsize=(12, 8))

plt.imshow(correlation)

plt.colorbar()

plt.xticks(
    range(len(correlation.columns)),
    correlation.columns,
    rotation=90
)

plt.yticks(
    range(len(correlation.columns)),
    correlation.columns
)

plt.title("Correlation Matrix")

plt.tight_layout()

plt.show()

# ------------------------------------------
# 29. Churn Percentage
# ------------------------------------------

churn_percentage = (
    df["Churn"]
    .value_counts(normalize=True)
    * 100
)

print("\nChurn Percentage:")
print(churn_percentage)

# ------------------------------------------
# 30. Operator-wise Churn Percentage
# ------------------------------------------

operator_churn_percentage = pd.crosstab(
    df["Operator"],
    df["Churn"],
    normalize="index"
) * 100

print("\nOperator-wise Churn Percentage:")
print(operator_churn_percentage)

# ------------------------------------------
# EDA Completed
# ------------------------------------------

print("\n====================================")
print("EDA COMPLETED SUCCESSFULLY!")
print("====================================")
# Out:
# Dataset loaded successfully!
#
# First 5 Rows:
#   Customer_ID Operator  Gender  Age  Tenure_Months Plan_Type Network_Type  \
# 0    CUST0001      Jio    Male   19             20   Prepaid           4G
# 1    CUST0002     BSNL  Female   23              1   Prepaid           4G
# 2    CUST0003   Airtel  Female   45             72   Prepaid           4G
# 3    CUST0004   Airtel  Female   46             63   Prepaid           4G
# 4    CUST0005      Jio  Female   43             67   Prepaid           4G
#
#    Monthly_Charges  Data_Usage_GB  Calls_Per_Month  Complaints Payment_Method  \
# 0           870.83           34.7              518           0            UPI
# 1          1161.21           22.7              261           2            UPI
# 2          1018.91           10.8             1185           2            UPI
# 3           913.49            8.4             1081           2    Credit Card
# 4          1095.71           48.5              853           2           Cash
#
# ...

# %%
import pandas as pd

df = pd.read_excel# Customer Churn Prediction
# Jio, Airtel, Vi and BSNL

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# -------------------------------------------------
# 1. Load Dataset
# -------------------------------------------------


data =pd.read_excel(r'C:\Users\kavyayarlagadda\Desktop/Customer churn prediction.xlsx')

print("Dataset loaded successfully!")
print("\nFirst 5 records:")
print(data.head())

print("\nDataset Shape:")
print(data.shape)

# -------------------------------------------------
# 2. Check Missing Values
# -------------------------------------------------

print("\nMissing Values:")
print(data.isnull().sum())

# -------------------------------------------------
# 3. Remove Customer ID
# -------------------------------------------------

data.drop("Customer_ID", axis=1, inplace=True)

# -------------------------------------------------
# 4. Convert Categorical Columns
# -------------------------------------------------

categorical_columns = data.select_dtypes(
    include=["object"]
).columns

label_encoders = {}

for column in categorical_columns:
    encoder = LabelEncoder()
    data[column] = encoder.fit_transform(data[column])
    label_encoders[column] = encoder

print("\nAfter Encoding:")
print(data.head())

# -------------------------------------------------
# 5. Separate Features and Target
# -------------------------------------------------

X = data.drop("Churn", axis=1)
y = data["Churn"]

# -------------------------------------------------
# 6. Train-Test Split
# -------------------------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("\nTraining Data:", X_train.shape)
print("Testing Data:", X_test.shape)

# -------------------------------------------------
# 7. Feature Scaling
# -------------------------------------------------

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# -------------------------------------------------
# 8. Logistic Regression
# -------------------------------------------------

logistic_model = LogisticRegression(
    max_iter=1000
)

logistic_model.fit(
    X_train_scaled,
    y_train
)

logistic_prediction = logistic_model.predict(
    X_test_scaled
)

logistic_accuracy = accuracy_score(
    y_test,
    logistic_prediction
)

print("\n--------------------------------")
print("LOGISTIC REGRESSION")
print("--------------------------------")

print("Accuracy:",
      logistic_accuracy * 100, "%")

print("\nClassification Report:")
print(
    classification_report(
        y_test,
        logistic_prediction
    )
)

# -------------------------------------------------
# 9. Random Forest
# -------------------------------------------------

random_forest = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

random_forest.fit(
    X_train,
    y_train
)

rf_prediction = random_forest.predict(
    X_test
)

rf_accuracy = accuracy_score(
    y_test,
    rf_prediction
)

print("\n--------------------------------")
print("RANDOM FOREST")
print("--------------------------------")

print("Accuracy:",
      rf_accuracy * 100, "%")

print("\nClassification Report:")
print(
    classification_report(
        y_test,
        rf_prediction
    )
)

# -------------------------------------------------
# 10. Compare Models
# -------------------------------------------------

print("\n================================")
print("MODEL COMPARISON")
print("================================")

print(
    "Logistic Regression Accuracy:",
    round(logistic_accuracy * 100, 2),
    "%"
)

print(
    "Random Forest Accuracy:",
    round(rf_accuracy * 100, 2),
    "%"
)

# -------------------------------------------------
# 11. Confusion Matrix
# -------------------------------------------------

cm = confusion_matrix(
    y_test,
    rf_prediction
)

plt.figure(figsize=(6, 5))

plt.imshow(cm)

plt.title("Customer Churn - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.xticks(
    [0, 1],
    ["No Churn", "Churn"]
)

plt.yticks(
    [0, 1],
    ["No Churn", "Churn"]
)

for i in range(2):
    for j in range(2):
        plt.text(
            j,
            i,
            cm[i, j],
            ha="center",
            va="center"
        )

plt.colorbar()
plt.show()

# -------------------------------------------------
# 12. Churn Distribution
# -------------------------------------------------

churn_counts = data["Churn"].value_counts()

plt.figure(figsize=(6, 5))

plt.bar(
    ["No Churn", "Churn"],
    [
        churn_counts.get(0, 0),
        churn_counts.get(1, 0)
    ]
)

plt.title("Customer Churn Distribution")
plt.xlabel("Churn Status")
plt.ylabel("Number of Customers")

plt.show()

# -------------------------------------------------
# 13. Operator-wise Customer Count
# -------------------------------------------------

# Original operator names are encoded.
# Decode them for display.

operator_encoder = label_encoders["Operator"]

operator_counts = data["Operator"].value_counts().sort_index()

operators = operator_encoder.inverse_transform(
    operator_counts.index
)

plt.figure(figsize=(7, 5))

plt.bar(
    operators,
    operator_counts.values
)

plt.title("Customers by Telecom Operator")
plt.xlabel("Operator")
plt.ylabel("Number of Customers")

plt.show()

# -------------------------------------------------
# 14. Feature Importance
# -------------------------------------------------

importance = random_forest.feature_importances_

feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": importance
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

print("\nFeature Importance:")
print(feature_importance)

plt.figure(figsize=(9, 6))

plt.barh(
    feature_importance["Feature"],
    feature_importance["Importance"]
)

plt.xlabel("Importance")
plt.ylabel("Feature")
plt.title("Random Forest Feature Importance")

plt.gca().invert_yaxis()

plt.show()

# -------------------------------------------------
# 15. Predict New Customer
# -------------------------------------------------

# Example:
# Customer using Airtel, age 25, tenure 3 months,
# prepaid, 4G, monthly charge 1200, etc.

new_customer = pd.DataFrame({
    "Operator": ["Airtel"],
    "Gender": ["Female"],
    "Age": [25],
    "Tenure_Months": [3],
    "Plan_Type": ["Prepaid"],
    "Network_Type": ["4G"],
    "Monthly_Charges": [1200],
    "Data_Usage_GB": [5],
    "Calls_Per_Month": [300],
    "Complaints": [3],
    "Payment_Method": ["UPI"],
    "Recharge_Frequency": ["Irregular"]
})

# Encode new customer using the same encoders')
new_customer.head()
# Out:
# Dataset loaded successfully!
#
# First 5 records:
#   Customer_ID Operator  Gender  Age  Tenure_Months Plan_Type Network_Type  \
# 0    CUST0001      Jio    Male   19             20   Prepaid           4G
# 1    CUST0002     BSNL  Female   23              1   Prepaid           4G
# 2    CUST0003   Airtel  Female   45             72   Prepaid           4G
# 3    CUST0004   Airtel  Female   46             63   Prepaid           4G
# 4    CUST0005      Jio  Female   43             67   Prepaid           4G
#
#    Monthly_Charges  Data_Usage_GB  Calls_Per_Month  Complaints Payment_Method  \
# 0           870.83           34.7              518           0            UPI
# 1          1161.21           22.7              261           2            UPI
# 2          1018.91           10.8             1185           2            UPI
# 3           913.49            8.4             1081           2    Credit Card
# 4          1095.71           48.5              853           2           Cash
#
# ...
